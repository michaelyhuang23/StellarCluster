# %%
import pandas as pd

# %%
basic_kinematics = pd.read_pickle('./data/archive/DR3_6D_kinematics.pkl')

# %%
IoM_kinematics = pd.read_hdf('./data/archive/common_kinematics_trimmed.h5', key='star')

# %%
IoM_kinematics.head()
# Out:
#              Etot         JR         Jphi         Jz            KE         Lx  \
# 3  -129912.710271  19.527907 -1844.018219   0.076847  32705.927249   9.274515
# 12 -116129.521791  87.863208 -2283.632715  14.659312  38137.430567 -83.855119
# 15 -133164.824427  25.303868 -1723.066234   0.474291  22849.968422 -23.725259
# 21 -125166.583355   6.877512 -2025.107026   4.045564  29599.360122 -80.059162
# 22 -135563.330455  27.848565 -1621.707861  10.124721  19698.120953 -62.648255
#
#             Ly           Lz             PE       ecc         peri        zmax  \
# 3   -12.791122 -1844.018219 -162618.637520  0.113374  7132.992374   44.460766
# 12  279.532118 -2283.632715 -154266.952358  0.229692  8176.550972  895.941822
# 15   11.017816 -1723.066234 -156014.792848  0.144805  6448.735755  108.924331
# 21   48.521084 -2025.107026 -154765.943477  0.064372  8290.214032  377.456591
# 22 -244.300844 -1621.707861 -155261.451407  0.154967  6052.901787  544.145945
#
#               source_id
# ...

# %%
basic_kinematics.head()
# Out:
#              source_id          ra        dec           l          b  \
# 0  5937084205616998400  251.710294 -51.457572  335.246137  -4.002339
# 1  5937210988670683648  250.147115 -51.178897  334.817572  -3.080853
# 2  5937218444729627264  250.378238 -51.051452  335.009369  -3.105632
# 3  5937230749895387648  249.680549 -51.275898  334.550707  -2.926726
# 4  2263182374669148416  294.338617  70.408659  102.216065  21.727761
#
#    parallax  parallax_nozpcorr  plx_over_error         r     r_err  ...  \
# 0  1.316443           1.288034       64.149973  7.440696  0.010932  ...
# 1  0.895456           0.854395       48.595710  7.128767  0.021377  ...
# 2  1.002764           0.958856       26.856087  7.231772  0.034470  ...
# 3  0.559254           0.517418        8.255543  6.554969  0.204967  ...
# 4       NaN           4.287576             NaN       NaN       NaN  ...
#
#       vr_err  vtheta_err  vphi_err        vabs  vabs_err  vabs_err_nocov  \
# ...

# %%
basic_kinematics.sort_values('source_id', inplace=True)

# %%
IoM_kinematics.sort_values('source_id', inplace=True)

# %%
basic_kinematics.tail()

# %%
IoM_kinematics.tail()
