# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_hdf('../../data/simulation/m12i_cluster_data_large_cluster_v2.h5', key='star')

# %%
sns.scatterplot(data=df, x='jphistar', y='jzstar')
# Out:
# <AxesSubplot: xlabel='jphistar', ylabel='jzstar'>

# %%
df['rstar'] = np.linalg.norm([df['xstar'], df['ystar'], df['zstar']], axis=0)
sns.kdeplot(data=df, x='rstar', y='star_mass')
# Out:
# <AxesSubplot:xlabel='rstar', ylabel='star_mass'>
