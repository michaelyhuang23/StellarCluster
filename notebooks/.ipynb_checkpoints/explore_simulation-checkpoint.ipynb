# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_hdf('../data/m12i_cluster_data_v2.h5', key='star')
df = df.reset_index()

# %%
df = df.iloc[np.random.choice(len(df), 1000)].copy()
df = df.reset_index()
df['rstar'] = np.linalg.norm([df['xstar'],df['ystar'],df['zstar']], axis=0)
sns.kdeplot(data=df, x='rstar', y='feH')
# Out:
# <AxesSubplot:xlabel='rstar', ylabel='feH'>

# %%
df['cluster_id_names']
sns.scatterplot(data=df, x='thetaphistar', y='thetarstar', hue='cluster_id_names')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /work2/08983/tg882826/stampede2/anaconda/envs/agama_env/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /work2/08983/tg882826/stampede2/anaconda/envs/agama_env/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /work2/08983/tg882826/stampede2/anaconda/envs/agama_env/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cluster_id_names'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df['cluster_id_names']
#       2 sns.scatterplot(data=df, x='thetaphistar', y='thetarstar', hue='cluster_id_names')
#
# File /work2/08983/tg882826/stampede2/anaconda/envs/agama_env/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File /work2/08983/tg882826/stampede2/anaconda/envs/agama_env/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'cluster_id_names'
