# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import plotly.express as px
import json

# %%
dataset = '../../data/caterpillar/labeled_caterpillar_data/labeled_94638_0'
df_ = pd.read_hdf(f'{dataset}.h5', key='star')
print(len(df_))
df_.head()
# Out:
# 48124
#          jzstar    jrstar  jphistar      vxstar      vystar      vzstar  \
# 35353  0.771706  1.066155 -1.248549 -158.509934  110.282841 -160.380032
# 35354  0.073215  1.133259 -0.012431  -25.212583  -30.772049  164.125576
# 35355  1.938071  2.291189  0.460224  -54.080167   14.284162 -189.270579
# 35356  2.481847  2.824102  0.220001   62.981674  -28.856594   -6.744534
# 35357  1.602451  0.905556 -0.205589   21.133583  -12.044617  182.430322
#
#           xstar     ystar     zstar  idstar  ...  snapstar      massstar  \
# 35353 -0.009334 -0.001382  0.000077   567.0  ...     162.0  1.778580e+08
# 35354  0.000622  0.000267 -0.014710   567.0  ...     162.0  1.778580e+08
# 35355  0.006917  0.006683 -0.030814   567.0  ...     162.0  1.778580e+08
# 35356  0.044120 -0.023708  0.012247   567.0  ...     162.0  1.778580e+08
# 35357  0.000254  0.009583  0.014926   567.0  ...     162.0  1.778580e+08
#
#        timestar  redshiftstar  cluster_id     rstar   phistar      vrstar  \
# 35353  4.228134      1.516271           1  0.009436 -2.994563  140.643193
# 35354  4.228134      1.516271           1  0.000677  0.404644  -35.291185
# 35355  4.228134      1.516271           1  0.009618  0.768162  -28.968992
# 35356  4.228134      1.516271           1  0.050086 -0.493077   69.138273
# 35357  4.228134      1.516271           1  0.009587  1.544284  -11.480142
#
#          vphistar       vstar
# 35353 -132.314764  251.016850
# 35354  -18.360981  168.878056
# 35355   47.848711  197.362747
# 35356    4.392440   69.605194
# 35357  -21.445454  184.044895
#
# [5 rows x 21 columns]

# %%
df_['cluster_id_name'] = [f'cluster {i}' for i in df_['cluster_id']]

# %%
sns.histplot(df_['redshiftstar'])
# Out:
# <AxesSubplot: xlabel='redshiftstar', ylabel='Count'>

# %%
df_recent = df_.copy()
df_recent = df_recent.loc[df_recent['redshiftstar']<1]

# %%
sns.scatterplot(data=df_recent, x='jphistar', y='estar', hue='cluster_id_name')
# Out:
# <AxesSubplot: xlabel='jphistar', ylabel='estar'>
