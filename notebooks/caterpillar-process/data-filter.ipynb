# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import plotly.express as px

# %%
df = pd.read_hdf('../../data/caterpillar/labeled_caterpillar_data/labeled_1354437_all.h5', key='star')
df.head()
# Out:
#          jzstar    jrstar  jphistar       vstar     xstar     ystar     zstar  \
# 64375  1.804622  9.504578 -0.103119   37.844583 -0.102755 -0.083423  0.056922
# 64376  2.488017  6.636684  0.648326   78.129878 -0.066458  0.044940 -0.071238
# 64377  7.348178  2.453728 -5.348804  134.409012 -0.061493  0.093857  0.012801
# 64378  8.310122  5.878459 -2.156659   65.615799 -0.067170  0.066039  0.125655
# 64379  6.545989  5.473257  4.538952   91.063606  0.020057 -0.143342  0.042605
#
#        idstar          estar  cluster_id
# 64375    36.0  118849.489274           1
# 64376    36.0  109473.975064           1
# 64377    36.0  113440.647147           1
# 64378    36.0  120869.169378           1
# 64379    36.0  119039.685553           1

# %%
Counter(df['cluster_id'].to_numpy()).most_common()
# Out:
# [(219, 483763),
#  (221, 220800),
#  (218, 204568),
#  (217, 82521),
#  (215, 80010),
#  (212, 60934),
#  (214, 51632),
#  (207, 39932),
#  (213, 39618),
#  (208, 13298),
#  (203, 9397),
#  (211, 7840),
#  (201, 7179),
#  (195, 7050),
#  (202, 4758),
#  (36, 4271),
#  (205, 4184),
#  (210, 3817),
#  (197, 3755),
#  (198, 3670),
#  (111, 3582),
#  (204, 3108),
#  (117, 2894),
#  (200, 2654),
#  (209, 2609),
#  (196, 2334),
#  (199, 2176),
#  (101, 2103),
#  (133, 2096),
#  (206, 1990),
#  (38, 1924),
#  (148, 1556),
#  (32, 1366),
#  (180, 1318),
#  (165, 1292),
#  (5, 1258),
#  (110, 1232),
#  (85, 1198),
#  (63, 1088),
#  (95, 1085),
#  (107, 1014),
#  (152, 994),
#  (169, 963),
#  (19, 942),
#  (48, 930),
#  (143, 928),
#  (157, 908),
#  (190, 887),
#  (43, 874),
#  (49, 867),
#  (60, 849),
#  (4, 826),
#  (22, 821),
#  (55, 780),
#  (88, 777),
#  (170, 766),
#  (39, 717),
#  (120, 712),
#  (128, 688),
#  (50, 674),
#  (155, 640),
#  (77, 628),
#  (137, 611),
#  (127, 610),
# ...
